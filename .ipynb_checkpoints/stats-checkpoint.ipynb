# %% [markdown]
# [https://www.reneshbedre.com/blog/anova.html](https://www.reneshbedre.com/blog/anova.html)

# %%
# !pip install bioinfokit
import numpy as np
# Out:
# Requirement already satisfied: bioinfokit in /home/tiago/.local/lib/python3.8/site-packages (2.0.8)
# Requirement already satisfied: numpy in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (1.22.2)
# Requirement already satisfied: seaborn in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (0.11.2)
# Requirement already satisfied: statsmodels in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (0.13.2)
# Requirement already satisfied: tabulate in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (0.8.10)
# Requirement already satisfied: adjustText in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (0.7.3)
# Requirement already satisfied: matplotlib in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (3.5.1)
# Requirement already satisfied: scipy in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (1.8.0)
# Requirement already satisfied: matplotlib-venn in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (0.11.7)
# Requirement already satisfied: pandas in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (1.4.3)
# Requirement already satisfied: textwrap3 in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (0.9.2)
# Requirement already satisfied: scikit-learn in /home/tiago/.local/lib/python3.8/site-packages (from bioinfokit) (1.1.1)
# Requirement already satisfied: packaging>=21.3 in /home/tiago/.local/lib/python3.8/site-packages (from statsmodels->bioinfokit) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/tiago/.local/lib/python3.8/site-packages (from statsmodels->bioinfokit) (0.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/tiago/.local/lib/python3.8/site-packages (from matplotlib->bioinfokit) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->bioinfokit) (7.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/tiago/.local/lib/python3.8/site-packages (from matplotlib->bioinfokit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tiago/.local/lib/python3.8/site-packages (from matplotlib->bioinfokit) (4.29.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tiago/.local/lib/python3.8/site-packages (from matplotlib->bioinfokit) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tiago/.local/lib/python3.8/site-packages (from matplotlib->bioinfokit) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tiago/.local/lib/python3.8/site-packages (from pandas->bioinfokit) (2022.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/tiago/.local/lib/python3.8/site-packages (from scikit-learn->bioinfokit) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tiago/.local/lib/python3.8/site-packages (from scikit-learn->bioinfokit) (3.1.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels->bioinfokit) (1.14.0)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
rcParams['font.size'] = 13
rcParams['figure.dpi'] = 300

fpga = 'smarthls'

import pandas as pd
# load data file
df = pd.read_csv('sbesc2022-project-metrics - ' + fpga + '.csv')

# %% [markdown]
# # BoxPlots

# %%
# reshape the d dataframe suitable for statsmodels package 
df = df.rename(columns={'NormMSE': 'MSE Measured', 'NormMSEO': 'MSE EvoApprox'})

df_melt = pd.melt(df.reset_index(), id_vars=['index'], value_vars=['MSE Measured','MSE EvoApprox'])
# replace column names
df_melt.columns = ['index', 'Normalized Metrics', 'Value']
df = df.rename(columns={'MSE Measured': 'NormMSE', 'MSE EvoApprox': 'NormMSEO'})

# generate a boxplot to see the data distribution by treatments. Using boxplot, we can 
# easily detect the differences between different treatments
import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.boxplot(x='Normalized Metrics', y='Value', data=df_melt, color='#99c2a2')
ax = sns.swarmplot(x="Normalized Metrics", y="Value", data=df_melt, color='#7d0013')
plt.savefig(fpga + '/boxplot-MSEvsMSEO.png')
plt.show()
################################################################################

# %%
df = df.rename(columns={'NormTPower': 'Power FPGA', 'NormPower': 'Power ASIC', 'NormLUTDFF': 'LUT+DFF', 'NormArea': 'Area ASIC'})

df_melt = pd.melt(df.reset_index(), id_vars=['index'], value_vars=['Power FPGA','Power ASIC', 'LUT+DFF','Area ASIC'])
# replace column names
df_melt.columns = ['index', 'Normalized Metrics', 'Value']

df = df.rename(columns={'Power FPGA': 'NormTPower', 'Power ASIC': 'NormPower', 'LUT+DFF': 'NormLUTDFF', 'Area ASIC': 'NormArea'})

# generate a boxplot to see the data distribution by treatments. Using boxplot, we can 
# easily detect the differences between different treatments
import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.boxplot(x='Normalized Metrics', y='Value', data=df_melt, color='#99c2a2')
ax = sns.swarmplot(x="Normalized Metrics", y="Value", data=df_melt, color='#7d0013')
plt.savefig(fpga + '/boxplot-TotalPowervsPower.png')
plt.show()
# Out:
# /home/tiago/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
if fpga == 'vivado':
  fpga2 = 'smarthls'
else:
  fpga2 = 'vivado'

df2 = pd.read_csv('sbesc2022-project-metrics - ' + fpga2 + '.csv')

df = df.rename(columns={'NormTPower': 'PolarFire Power', 'NormLUTDFF': 'PolarFire LUT+DFF'})
df2 = df2.rename(columns={'NormTPower': 'Arty Power', 'NormLUTDFF': 'Arty LUT+DFF'})
df3 = pd.merge(df,df2,on='Adder', how='inner')

# %%
df_melt = pd.melt(df3.reset_index(), id_vars=['index'], value_vars=['PolarFire Power','Arty Power', 'PolarFire LUT+DFF','Arty LUT+DFF'])
# replace column names
df_melt.columns = ['index', 'Normalized Metrics', 'Value']

# generate a boxplot to see the data distribution by treatments. Using boxplot, we can 
# easily detect the differences between different treatments
import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.boxplot(x='Normalized Metrics', y='Value', data=df_melt, color='#99c2a2')
ax = sns.swarmplot(x="Normalized Metrics", y="Value", data=df_melt, color='#7d0013')
plt.savefig('boxplot-SmartvsXilinx.png')
plt.show()
# Out:
# /home/tiago/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 10.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df = df.rename(columns={'PolarFire Power': 'NormTPower', 'PolarFire LUT+DFF': 'NormLUTDFF'})

# %% [markdown]
# #Stat tests

# %% [markdown]
# ## MSE vs MSEO

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
df = df.rename(columns={'MSEO': 'MSE EvoApprox'})

df_melt = pd.melt(df.reset_index(), id_vars=['index'], value_vars=['MSE','MSE EvoApprox'])
# replace column names
df_melt.columns = ['index', 'Metrics', 'Value']
fvalue, pvalue = stats.f_oneway(df['MSE'], df['MSE EvoApprox'])
#print(fvalue, pvalue)
# 17.492810457516338 2.639241146210922e-05

# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('Value ~ C(Metrics)', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df_melt, res_var='Value', anova_model='Value ~ C(Metrics)')
res.anova_summary
# Out:
#               df        sum_sq       mean_sq         F   PR(>F)
# C(Metrics)   1.0  7.276184e+07  7.276184e+07  7.241046  0.01097
# Residual    34.0  3.416499e+08  1.004853e+07       NaN      NaN

# %%
# we will use bioinfokit (v1.0.3 or later) for performing tukey HSD test
# check documentation here https://github.com/reneshbedre/bioinfokit
from bioinfokit.analys import stat
# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test
res = stat()
res.tukey_hsd(df=df_melt, res_var='Value', xfac_var='Metrics', anova_model='Value ~ C(Metrics)')
res.tukey_summary
# Out:
# /home/tiago/.local/lib/python3.8/site-packages/bioinfokit/analys.py:402: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
#   group1         group2         Diff       Lower        Upper   q-value  \
# 0    MSE  MSE EvoApprox  2843.351667  695.986542  4990.716791  3.805534
#
#    p-value
# 0  0.01097

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.savefig(fpga + '/Quantiles-MSEvsMSEO.png')
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.savefig(fpga + '/Frequency-MSEvsMSEO.png')
plt.show()

# %%
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)

import scipy.stats as stats
w, pvalue = stats.bartlett(df['MSE'], df['MSE EvoApprox'])
print(w, pvalue)

# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the bartlett's test
from bioinfokit.analys import stat 
res = stat()
res.bartlett(df=df_melt, res_var='Value', xfac_var='Metrics')
res.bartlett_summary

df = df.rename(columns={'MSE EvoApprox': 'MSEO'})

# %% [markdown]
# ## TotalPower vs Power

# %%
import scipy.stats as stats
df = df.rename(columns={'TotalPower': 'FPGA Power', 'Power': 'ASIC Power'})


df_melt = pd.melt(df.reset_index(), id_vars=['index'], value_vars=['FPGA Power','ASIC Power'])
# replace column names
df_melt.columns = ['index', 'Metrics', 'Value']
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df['FPGA Power'], df['ASIC Power'])
#print(fvalue, pvalue)
# 17.492810457516338 2.639241146210922e-05

# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('Value ~ C(Metrics)', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df_melt, res_var='Value', anova_model='Value ~ C(Metrics)')
res.anova_summary

# %%
# we will use bioinfokit (v1.0.3 or later) for performing tukey HSD test
# check documentation here https://github.com/reneshbedre/bioinfokit
from bioinfokit.analys import stat
# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test
res = stat()
res.tukey_hsd(df=df_melt, res_var='Value', xfac_var='Metrics', anova_model='Value ~ C(Metrics)')
res.tukey_summary

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.savefig(fpga + '/Quantiles-TotalPowervsPower.png')
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.savefig(fpga + '/Frequency-TotalPowervsPower.png')
plt.show()

# %%
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)

import scipy.stats as stats
w, pvalue = stats.bartlett(df['FPGA Power'], df['ASIC Power'])
print(w, pvalue)

# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the bartlett's test
from bioinfokit.analys import stat 
res = stat()
res.bartlett(df=df_melt, res_var='Value', xfac_var='Metrics')
res.bartlett_summary

df = df.rename(columns={'FPGA Power': 'TotalPower', 'ASIC Power': 'Power'})

# %% [markdown]
# ##LUT+DFF vs Area

# %%
import scipy.stats as stats
df = df.rename(columns={'LUTDFF': 'LUT+DFF'})

df_melt = pd.melt(df.reset_index(), id_vars=['index'], value_vars=['LUT+DFF','Area'])
# replace column names
df_melt.columns = ['index', 'Metrics', 'Value']
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df['LUT+DFF'], df['Area'])
#print(fvalue, pvalue)
# 17.492810457516338 2.639241146210922e-05

# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('Value ~ C(Metrics)', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df_melt, res_var='Value', anova_model='Value ~ C(Metrics)')
res.anova_summary

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.savefig(fpga + '/Quantiles-LUT+DFFvsArea.png')
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.savefig(fpga + '/Frequency-LUT+DFFvsArea.png')
plt.show()

# %%
# we will use bioinfokit (v1.0.3 or later) for performing tukey HSD test
# check documentation here https://github.com/reneshbedre/bioinfokit
from bioinfokit.analys import stat
# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test
res = stat()
res.tukey_hsd(df=df_melt, res_var='Value', xfac_var='Metrics', anova_model='Value ~ C(Metrics)')
res.tukey_summary

# %%
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)

import scipy.stats as stats
w, pvalue = stats.bartlett(df['LUT+DFF'], df['Area'])
print(w, pvalue)

# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the bartlett's test
from bioinfokit.analys import stat 
res = stat()
res.bartlett(df=df_melt, res_var='Value', xfac_var='Metrics')
res.bartlett_summary

df = df.rename(columns={'LUT+DFF': 'LUTDFF'})

# %% [markdown]
# ## SmartHLS vs Xilinx

# %%
if fpga == 'vivado':
  fpga2 = 'smarthls'
else:
  fpga2 = 'vivado'

df2 = pd.read_csv('sbesc2022-project-metrics - ' + fpga2 + '.csv')

df = df.rename(columns={'TotalPower': 'PolarFire Power', 'LUTDFF': 'PolarFire LUT+DFF'})
df2 = df2.rename(columns={'TotalPower': 'Arty Power', 'LUTDFF': 'Arty LUT+DFF'})
df3 = pd.merge(df,df2,on='Adder', how='inner')

# %% [markdown]
# ### LUT

# %%
import scipy.stats as stats

df_melt = pd.melt(df3.reset_index(), id_vars=['index'], value_vars=['PolarFire LUT+DFF','Arty LUT+DFF'])
# replace column names
df_melt.columns = ['index', 'Metrics', 'Value']
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df3['PolarFire LUT+DFF'], df3['Arty LUT+DFF'])
#print(fvalue, pvalue)
# 17.492810457516338 2.639241146210922e-05

# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('Value ~ C(Metrics)', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df_melt, res_var='Value', anova_model='Value ~ C(Metrics)')
res.anova_summary

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.savefig('Quantiles-LUTSmartvsXilinx.png')
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.savefig('Frequency-LUTSmartvsXilinx.png')
plt.show()

# %%
# we will use bioinfokit (v1.0.3 or later) for performing tukey HSD test
# check documentation here https://github.com/reneshbedre/bioinfokit
from bioinfokit.analys import stat
# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test
res = stat()
res.tukey_hsd(df=df_melt, res_var='Value', xfac_var='Metrics', anova_model='Value ~ C(Metrics)')
res.tukey_summary

# %%
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)

import scipy.stats as stats
w, pvalue = stats.bartlett(df3['PolarFire LUT+DFF'], df3['Arty LUT+DFF'])
print(w, pvalue)

# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the bartlett's test
from bioinfokit.analys import stat 
res = stat()
res.bartlett(df=df_melt, res_var='Value', xfac_var='Metrics')
res.bartlett_summary

# %% [markdown]
# ### Power

# %%
import scipy.stats as stats

df_melt = pd.melt(df3.reset_index(), id_vars=['index'], value_vars=['PolarFire Power','Arty Power'])
# replace column names
df_melt.columns = ['index', 'Metrics', 'Value']
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df3['PolarFire Power'], df3['Arty Power'])
#print(fvalue, pvalue)
# 17.492810457516338 2.639241146210922e-05

# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('Value ~ C(Metrics)', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# ANOVA table using bioinfokit v1.0.3 or later (it uses wrapper script for anova_lm)
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df_melt, res_var='Value', anova_model='Value ~ C(Metrics)')
res.anova_summary

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.savefig('Quantiles-PowerSmartvsXilinx.png')
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.savefig('Frequency-PowerSmartvsXilinx.png')
plt.show()

# %%
# we will use bioinfokit (v1.0.3 or later) for performing tukey HSD test
# check documentation here https://github.com/reneshbedre/bioinfokit
from bioinfokit.analys import stat
# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test
res = stat()
res.tukey_hsd(df=df_melt, res_var='Value', xfac_var='Metrics', anova_model='Value ~ C(Metrics)')
res.tukey_summary

# %%
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)

import scipy.stats as stats
w, pvalue = stats.bartlett(df3['PolarFire Power'], df3['Arty Power'])
print(w, pvalue)

# if you have a stacked table, you can use bioinfokit v1.0.3 or later for the bartlett's test
from bioinfokit.analys import stat 
res = stat()
res.bartlett(df=df_melt, res_var='Value', xfac_var='Metrics')
res.bartlett_summary

# %%
df = df.rename(columns={'PolarFire Power': 'TotalPower', 'PolarFire LUT+DFF': 'LUTDFF'})

# %% [markdown]
# #Correlation Plots

# %% [markdown]
# # General Plots

# %%
rcParams['figure.figsize'] = 12, 3
rcParams['font.size'] = 10

if fpga == 'vivado':
  fpga2 = 'smarthls'
else:
  fpga2 = 'vivado'

df2 = pd.read_csv('sbesc2022-project-metrics - ' + fpga2 + '.csv')

df = df.rename(columns={'NormTPower': 'PolarFire Power', 'LUTDFF': 'PolarFire LUT+DFF'})
df2 = df2.rename(columns={'NormTPower': 'Arty Power', 'LUTDFF': 'Arty LUT+DFF'})

df3 = pd.merge(df,df2,on='Adder', how='inner')
ax = plt.figure().add_subplot(111)
df3.plot(ax=ax, y=["PolarFire LUT+DFF", "Arty LUT+DFF"], x="Adder", kind="bar")

bars = ax.patches
hatches = ''.join(h*len(df3) for h in '\\+')

for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Quantity')
plt.savefig('LUTMicrochipvsXilinx.png', bbox_inches = 'tight')
plt.show()

ax = plt.figure().add_subplot(111)
df3.plot(ax=ax, y=["PolarFire Power", "Arty Power"], x="Adder", kind="bar")

bars = ax.patches
hatches = ''.join(h*len(df3) for h in '\\+')

for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Power (mW)')
plt.savefig('PowerMicrochipvsXilinx.png', bbox_inches = 'tight')
plt.show()

df = df.rename(columns={'PolarFire Power':'NormTPower', 'PolarFire LUT+DFF':'LUTDFF'})
